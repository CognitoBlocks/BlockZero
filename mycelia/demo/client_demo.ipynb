# %%
from mycelia.shared.client import download_model, submit_model
from mycelia.shared.chain import *
from mycelia.shared.app_logging import configure_logging
from mycelia.shared.checkpoint import (
    get_resume_info,
)
from mycelia.shared.config import MinerConfig
import bittensor 

configure_logging()

config = MinerConfig()
config.model.device = "cuda:2"
config = MinerConfig.from_path("/home/isabella/crucible/subnet-MoE/checkpoints/miner/miner/hk1/foundation/config.yaml")
wallet, subtensor = setup_chain_worker(config)

url = "localhost:8001"
# Out:
# 2025-12-16 02:50:16 [warning  ] Cannot find the wallet key by name coldkey name: template_coldkey_name, hotkey name: template_hotkey_name, please make sure it has been set correctly if you are reloading from a  or use --hotkey_name & --coldkey_name when you are creating a config file from a template. [mycelia.shared.config] error=Generic error: Failed to get hotkey: FileNotFound("Keyfile at: /home/isabella/.bittensor/wallets/template_coldkey_name/hotkeys/template_hotkey_name does not exist.")
# keepalive ping failed
# TimeoutError: timed out while closing connection
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/isabella/crucible/subnet-MoE/.venv/lib/python3.10/site-packages/websockets/sync/connection.py", line 777, in keepalive
#     with self.send_context():
#   File "/usr/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/isabella/crucible/subnet-MoE/.venv/lib/python3.10/site-packages/websockets/sync/connection.py", line 1012, in send_context
#     raise self.protocol.close_exc from original_exc
# websockets.exceptions.ConnectionClosedError: sent 1011 (internal error) keepalive ping timeout; no close frame received
# keepalive ping failed
# TimeoutError: timed out while closing connection
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/isabella/crucible/subnet-MoE/.venv/lib/python3.10/site-packages/websockets/sync/connection.py", line 777, in keepalive
#     with self.send_context():
#   File "/usr/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/isabella/crucible/subnet-MoE/.venv/lib/python3.10/site-packages/websockets/sync/connection.py", line 1012, in send_context
#     raise self.protocol.close_exc from original_exc
# websockets.exceptions.ConnectionClosedError: sent 1011 (internal error) keepalive ping timeout; no close frame received

# %%
import requests

def ping_url(url, timeout=3):
    try:
        r = requests.get(url, timeout=timeout, allow_redirects=True)
        return r.text
    
    except requests.RequestException as e:
        return None

ping_url(f"http://{url}/ping")
# Out:
# '{"status":"ok"}'

# %%
download_model(
    url=f"http://{url}/get-checkpoint",
    my_hotkey=wallet.hotkey,  # type: ignore
    target_hotkey_ss58="5DoHdXfDYraqPzkLjrXGMZxvGXYdDYhuC8tGbQdb4zvz2LbH",
    block=subtensor.block,
    expert_group_id=config.task.expert_group_id,
    token=getattr(config.cycle, "token", ""),
    out_dir=config.ckpt.validator_checkpoint_path / f"uid{4}_{'hk3'}.pt",
)
# Out:
# 2025-12-16 02:53:56 [info     ] HTTP response received       [mycelia.shared.client] status_code=200
# Downloading: 113.00 MiB / 3.38 GiB (  3.3%) @ 224.97 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 242.00 MiB / 3.38 GiB (  7.0%) @ 241.40 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 360.00 MiB / 3.38 GiB ( 10.4%) @ 239.52 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 477.00 MiB / 3.38 GiB ( 13.8%) @ 237.83 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 599.00 MiB / 3.38 GiB ( 17.3%) @ 238.98 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 747.00 MiB / 3.38 GiB ( 21.6%) @ 248.31 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 892.00 MiB / 3.38 GiB ( 25.8%) @ 253.99 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 1.03 GiB / 3.38 GiB ( 30.4%) @ 261.77 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 1.21 GiB / 3.38 GiB ( 36.0%) @ 275.45 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 1.43 GiB / 3.38 GiB ( 42.2%) @ 290.98 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 1.65 GiB / 3.38 GiB ( 48.9%) @ 306.21 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 1.84 GiB / 3.38 GiB ( 54.5%) @ 312.96 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 2.03 GiB / 3.38 GiB ( 60.1%) @ 318.33 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 2.22 GiB / 3.38 GiB ( 65.8%) @ 323.76 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 2.41 GiB / 3.38 GiB ( 71.4%) @ 328.11 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 2.66 GiB / 3.38 GiB ( 78.8%) @ 339.24 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 2.86 GiB / 3.38 GiB ( 84.6%) @ 343.01 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 3.05 GiB / 3.38 GiB ( 90.4%) @ 346.13 MiB/s [mycelia.shared.client] end= flush=True
# Downloading: 3.25 GiB / 3.38 GiB ( 96.3%) @ 349.11 MiB/s [mycelia.shared.client] end= flush=True
# Done:       3.38 GiB / 3.38 GiB (100.0%) in 22.2s @ 155.40 MiB/s [mycelia.shared.client]

# %%
import torch 
# org 
sd = torch.load("/home/isabella/crucible/subnet-MoE/checkpoints/validator/validator/hk1/foundation/globalver_3/model_expgroup_0.pt")

# %%
import torch
# transfered
sd = torch.load(config.ckpt.validator_checkpoint_path / f"uid{4}_{'hk3'}.pt")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[9], line 2
#       1 import torch
# ----> 2 sd = torch.load(config.ckpt.validator_checkpoint_path / f"uid{4}_{'hk3'}.pt")
#
# File ~/crucible/subnet-MoE/.venv/lib/python3.10/site-packages/torch/serialization.py:1553, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1546         return _legacy_load(
#    1547             opened_file,
#    1548             map_location,
#    1549             _weights_only_unpickler,
#    1550             **pickle_load_args,
#    1551         )
#    1552     except pickle.UnpicklingError as e:
# -> 1553         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1554 return _legacy_load(
#    1555     opened_file, map_location, pickle_module, **pickle_load_args
#    1556 )
#
# UnpicklingError: Weights only load failed. In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# Please file an issue with the following so that we can make `weights_only=True` compatible with your use case: WeightsUnpickler error:
#
# Unsupported operand 80
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
from pathlib import Path

resume, start_step, latest_checkpoint_path = get_resume_info(rank=0, config=config)
submit_model(
    url="http://localhost:8000/submit-checkpoint",
    token="",
    step=0,
    uid=1,
    hotkey=config.chain.hotkey_ss58,
    model_path=Path(latest_checkpoint_path) / "model.pt",
)
# Out:
# 2025-12-16 01:22:25 [info     ] Looking for checkpoint from folder [mycelia.shared.checkpoint] path={PosixPath('/home/isabella/crucible/subnet-MoE/checkpoints/miner/miner/hk1/foundation')} result=found
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 from pathlib import Path
#       3 resume, start_step, latest_checkpoint_path = get_resume_info(rank=0, config=config)
# ----> 4 submit_model(
#       5     url="http://localhost:8000/submit-checkpoint",
#       6     token="",
#       7     step=0,
#       8     uid=1,
#       9     hotkey=config.chain.hotkey_ss58,
#      10     model_path=Path(latest_checkpoint_path) / "model.pt",
#      11 )
#
# TypeError: submit_model() got an unexpected keyword argument 'step'
