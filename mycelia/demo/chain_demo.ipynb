# %%
from mycelia.shared.client import download_model, submit_model
from mycelia.shared.chain import *
from mycelia.shared.app_logging import configure_logging
from mycelia.shared.checkpoint import (
    get_resume_info,
)
from mycelia.shared.config import MinerConfig
import bittensor 

configure_logging()

miner_config = MinerConfig.from_path("/home/isabella/crucible/subnet-MoE/checkpoints/miner/miner/hk1/foundation/config.yaml")
wallet, subtensor = setup_chain_worker(miner_config)

# %%
miner_config
# Out:
# MinerConfig(run=RunCfg(run_name='foundation', root_path=PosixPath('/home/isabella/crucible/subnet-MoE')), chain=ChainCfg(netuid=348, uid=13, hotkey_ss58='5FnRrHZ2KDecJzytUdwz4sfBd4YW6JReYNZTHK7xRBM7jqx9', coldkey_ss58='5Eyjg3S1hT7R6dMFPCLTzaSD96AFKYvEE2NdXejAUtevYvKU', ip='0.0.0.0', port=8002, role='miner', coldkey_name='miner', hotkey_name='hk1', network='test'), model=ModelCfg(model_path='Qwen/Qwen3-Next-80B-A3B-Thinking', foundation=True, torch_compile=False, attn_implementation='sdpa', precision='fp16-mixed', device='cuda'), moe=MoECfg(my_expert_group_id=1, dense_to_moe=True, interleave=True, noise=False, noise_std=0.1, num_experts=8, num_experts_per_tok=2, partial_topk=1, full_topk=2, aux_load_balance=False, router_aux_loss_coef=1.0, partial_moe=True, num_worker_groups=2, rotate_expert=False, expert_rotate_interval=100), ckpt=CheckpointCfg(resume_from_ckpt=True, base_checkpoint_path=PosixPath('/home/isabella/crucible/subnet-MoE/checkpoints/miner'), checkpoint_path=PosixPath('/home/isabella/crucible/subnet-MoE/checkpoints/miner/miner/hk1/foundation'), checkpoint_interval=20, full_validation_interval=20, checkpoint_topk=5, validator_checkpoint_path=PosixPath('/home/isabella/crucible/subnet-MoE/checkpoints/miner/validator_checkpoint')), sched=ScheduleCfg(warmup_steps=0, total_steps=88000), log=LoggingCfg(log_wandb=False, wandb_project_name='test-moe', wandb_resume=False, wandb_full_id='oo2vn2v4', wandb_partial_id=['3q8mckj8'], base_metric_path=PosixPath('/home/isabella/crucible/subnet-MoE/metrics'), metric_path=PosixPath('/home/isabella/crucible/subnet-MoE/metrics/foundation.csv'), metric_interval=20), opt=OptimizerCfg(lr=2e-05, outer_lr=0.7, outer_momentum=0.9), cycle=CycleCfg(cycle_length=45, distribute_period=2, train_period=10, commit_period=3, submission_period=10, validate_period=10, merge_period=10, owner_url='http://149.137.225.62:7000'), task=TaskCfg(expert_group_name='exp_math', base_path=PosixPath('/home/isabella/crucible/subnet-MoE/expert_groups'), path=PosixPath('/home/isabella/crucible/subnet-MoE/expert_groups/exp_math'), exp=ExpertCfg(data=DataCfg(dataset_name='open-r1/OpenR1-Math-220k', data_dir=None, batch_size=1, sequence_length=100, per_device_train_batch_size=2, world_size=10, rank=1, dataset_class='expert_groups.exp_math.dataset:StreamingTorchDataset', vali_fraction=0.1), group_id=0)), role='miner', local_par=ParallelismCfg(gradient_accumulation_steps=5, global_opt_interval=100, world_size=1, port=29500, ip_address='127.0.0.1'))

# %%
miner_config.write()
# Out:
# 2026-01-13 05:31:26 [info     ] Wrote config to /home/isabella/crucible/subnet-MoE/checkpoints/miner/miner/hk1/foundation/config.yaml [mycelia.shared.config]

# %%
import pandas as pd 
from mycelia.shared.chain import get_chain_commits

commits = get_chain_commits(config = miner_config, subtensor = subtensor)

# %%
df = pd.DataFrame([ {**c.__dict__, **n.__dict__} for c,n in commits if c is not None])
df.axon_info
# Out:
# 0    AxonInfo( /ipv4/64.247.196.162:8000, 5Fsqn57MZ...
# 1    AxonInfo( /ipv4/149.137.225.62:8001, 5DoHdXfDY...
# 2    AxonInfo( /ipv4/149.137.225.62:8001, 5DUqbhkpv...
# 3    AxonInfo( /ipv4/149.137.225.62:8002, 5FnRrHZ2K...
# Name: axon_info, dtype: object

# %%
from mycelia.shared.cycle import get_phase
config.cycle.owner_url = "http://149.137.225.62:7000"

get_phase(config)
# Out:
# PhaseResponse(block=6248896, cycle_length=45, cycle_index=138864, cycle_block_index=16, phase_name='Submission', phase_index=3, phase_start_block=6248895, phase_end_block=6248904, blocks_into_phase=1, blocks_remaining_in_phase=8)
